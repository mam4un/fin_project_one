# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import alpaca_trade_api as tradeapi
from MCForecastTools import MCSimulation

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")
api = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2"
)

# %%
ticker_sect = ["XLB", "XLP", "XLC", "XLV", "XLI", "XLK", "XLY", "XLU", "XLF", "XLE", "XLFE"]
timeframe = "1D"
start_date = pd.Timestamp("2000-01-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2020-12-01", tz="America/New_York").isoformat()

# %%
sector_data = api.get_barset(
    ticker_sect,
    timeframe,
    start=start_date,
    end=end_date
).df

sector_data.head()
# Out:
#                              XLB                                 XLC           \
#                             open   high    low  close    volume open high low
# time
# 2008-01-02 05:00:00+00:00  41.70  41.95  40.98  41.33   9483635  NaN  NaN NaN
# 2008-01-03 05:00:00+00:00  41.52  42.17  41.45  41.80   8699808  NaN  NaN NaN
# 2008-01-04 05:00:00+00:00  41.42  41.57  40.70  40.74  13370213  NaN  NaN NaN
# 2008-01-07 05:00:00+00:00  40.81  41.06  39.67  40.25  16971407  NaN  NaN NaN
# 2008-01-08 05:00:00+00:00  40.40  41.07  39.55  39.60  21112177  NaN  NaN NaN
#
#                                         ...    XLV                       \
#                           close volume  ...   open   high    low  close
# time                                    ...
# 2008-01-02 05:00:00+00:00   NaN    NaN  ...  35.63  35.63  34.86  34.94
# 2008-01-03 05:00:00+00:00   NaN    NaN  ...  34.98  35.30  34.56  35.18
# 2008-01-04 05:00:00+00:00   NaN    NaN  ...  35.01  35.16  34.50  34.83
# ...

# %%
sector_data.to_csv("sector_data.csv")

# %%
ticker_eem = ["EWY", "EPI", "FXI", "RSX", "EWW", "EWZ", "EEM"]

emerging_market_data = api.get_barset(
    ticker_eem,
    timeframe,
    start=start_date,
    end=end_date
).df

emerging_market_data.head()
# Out:
#                               EEM                                     EPI  \
#                              open    high     low   close     volume open
# time
# 2008-01-02 00:00:00-05:00  13.660  50.203  13.263  13.353  135382380  NaN
# 2008-01-03 00:00:00-05:00  13.517  13.580  13.427  13.473  154777641  NaN
# 2008-01-04 00:00:00-05:00  13.360  48.460  13.023  48.217  207042127  NaN
# 2008-01-07 00:00:00-05:00  48.623  48.933  13.023  13.163   86060487  NaN
# 2008-01-08 00:00:00-05:00  13.357  13.483  13.053  13.063  298762564  NaN
#
#                                                  ...     FXI                  \
#                           high low close volume  ...    open    high     low
# time                                             ...
# 2008-01-02 00:00:00-05:00  NaN NaN   NaN    NaN  ...  57.247  57.620  55.733
# 2008-01-03 00:00:00-05:00  NaN NaN   NaN    NaN  ...  55.767  56.453  55.467
# 2008-01-04 00:00:00-05:00  NaN NaN   NaN    NaN  ...  55.997  55.997  54.377
# ...

# %%
emerging_market_data.to_csv("emerging_market_data.csv")

# %%
ticker_govt_credit = ["TLT", "TIP", "MUB", "SHY", "IEF", "BIL"]

govt_credit_data = api.get_barset(
    ticker_govt_credit,
    timeframe,
    start=start_date,
    end=end_date
).df

govt_credit_data.head()
# Out:
#                              BIL                                 IEF         \
#                             open   high    low  close  volume   open   high
# time
# 2008-01-02 00:00:00-05:00  91.64  91.66  91.58  91.66   29441  86.99  87.73
# 2008-01-03 00:00:00-05:00  91.66  91.66  91.60  91.60   30455  87.50  87.84
# 2008-01-04 00:00:00-05:00  91.70  91.70  91.54  91.58  171218  88.00  88.24
# 2008-01-07 00:00:00-05:00  91.60  91.66  91.58  91.66   30300  87.87  88.30
# 2008-01-08 00:00:00-05:00  91.64  91.68  91.56  91.60   18350  88.09  88.40
#
#                                                    ...     TIP          \
#                              low  close    volume  ...    open    high
# time                                               ...
# 2008-01-02 00:00:00-05:00  86.94  87.65  475697.0  ...  106.02  106.71
# 2008-01-03 00:00:00-05:00  87.31  87.77  192486.0  ...  106.45  107.00
# 2008-01-04 00:00:00-05:00  87.95  87.99  367465.0  ...  107.17  107.23
# ...

# %%
govt_credit_data.to_csv("govt_credit_data.csv")

# %%
ticker_commodities = ["USL", "UNL", "GLD", "SLV", "DBB", "CORN", "SOYB", "DBC", "GSG"]

commodities_data = api.get_barset(
    ticker_commodities,
    timeframe,
    start=start_date,
    end=end_date
).df

commodities_data.head()
# Out:
#                           CORN                          DBB                \
#                           open high low close volume   open   high    low
# time
# 2008-01-02 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  22.20  22.51  22.08
# 2008-01-03 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  22.65  23.39  22.65
# 2008-01-04 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  23.19  23.19  22.77
# 2008-01-07 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  22.79  22.93  22.66
# 2008-01-08 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  23.20  23.81  23.20
#
#                                             ...  UNL                        \
#                            close    volume  ... open high low close volume
# time                                        ...
# 2008-01-02 00:00:00-05:00  22.30   22200.0  ...  NaN  NaN NaN   NaN    NaN
# 2008-01-03 00:00:00-05:00  23.38   36400.0  ...  NaN  NaN NaN   NaN    NaN
# 2008-01-04 00:00:00-05:00  22.82  103400.0  ...  NaN  NaN NaN   NaN    NaN
# ...

# %%
commodities_data.to_csv("commodities_data.csv")

# %%
ticker_corp_credit = ["HYG", "LQD"]

corp_credit_data = api.get_barset(
    ticker_corp_credit,
    timeframe,
    start=start_date,
    end=end_date
).df

corp_credit_data.head()
# Out:
#                               HYG                                   LQD  \
#                              open    high    low  close  volume    open
# time
# 2008-01-02 00:00:00-05:00   99.56  100.90  99.30  99.50   61800  105.26
# 2008-01-03 00:00:00-05:00   99.60   99.95  99.26  99.50   62314  105.36
# 2008-01-04 00:00:00-05:00  100.01  100.05  98.84  98.85   46350  106.29
# 2008-01-07 00:00:00-05:00   99.49   99.49  98.30  98.30  133005  106.55
# 2008-01-08 00:00:00-05:00   99.49   99.49  98.00  98.04   42050  106.54
#
#
#                              high     low   close  volume
# time
# 2008-01-02 00:00:00-05:00  106.22  105.06  106.03  468377
# 2008-01-03 00:00:00-05:00  106.04  105.36  105.91  150695
# 2008-01-04 00:00:00-05:00  106.61  106.11  106.50  135286
# 2008-01-07 00:00:00-05:00  106.71  106.25  106.66  148029
# 2008-01-08 00:00:00-05:00  106.61  105.99  106.28  126675

# %%
corp_credit_data.to_csv("corp_credit_data.csv")

# %%
ticker_markets = ["SPY", "IWM", "QQQ", "IWF"]

markets_data = api.get_barset(
    ticker_markets,
    timeframe,
    start=start_date,
    end=end_date
).df

markets_data.head()
# Out:
#                              IWF                                    IWM  \
#                             open   high    low  close     volume   open
# time
# 2008-01-02 00:00:00-05:00  60.95  61.08  59.81  60.12  4881050.0  76.15
# 2008-01-03 00:00:00-05:00  60.13  60.44  59.85  60.08  3134382.0  75.17
# 2008-01-04 00:00:00-05:00  59.58  59.58  58.31  58.39  3488363.0  73.23
# 2008-01-07 00:00:00-05:00  58.61  58.74  57.79  58.39  5370530.0  72.21
# 2008-01-08 00:00:00-05:00  58.70  59.00  57.04  57.25  5621529.0  72.37
#
#                                                                QQQ         \
#                             high    low  close       volume   open   high
# time
# 2008-01-02 00:00:00-05:00  76.50  74.59  75.08   89163396.0  51.27  51.47
# 2008-01-03 00:00:00-05:00  75.62  74.03  74.07   72696175.0  50.39  50.76
# 2008-01-04 00:00:00-05:00  73.33  71.61  71.87  105483531.0  49.79  49.83
# 2008-01-07 00:00:00-05:00  72.85  71.07  72.10  124193191.0  48.41  48.68
# ...

# %%
markets_data.to_csv("markets_data.csv")
